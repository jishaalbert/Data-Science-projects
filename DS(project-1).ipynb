# %%
import pandas as pd

# %%
df=pd.read_csv('dataset.csv.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 9 columns]

# %%
import numpy as np

# %% [markdown]
# # height

# %%
df['Height']=np.random.uniform(150,180,size=len(df))
df
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  151.221031     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  161.849102     235
# 2     John Holland  Boston Celtics      30       SG   27  159.902120     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  155.441078     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  157.551638     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  154.333318     203
# 454      Raul Neto       Utah Jazz      25       PG   24  175.350238     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  153.808051     256
# 456    Jeff Withey       Utah Jazz      24        C   26  158.238952     231
# 457       Priyanka       Utah Jazz      34        C   25  154.367278     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 9 columns]

# %% [markdown]
# # percentage and count

# %%
print(df.count())
# Out:
# Name        458
# Team        458
# Number      458
# Position    458
# Age         458
# Height      458
# Weight      458
# College     374
# Salary      447
# dtype: int64

# %% [markdown]
# # which team is high salary

# %%
spending=df.groupby(['Team','Position'])['Salary'].sum()
print(spending)
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: float64

# %%
highest_spending=spending.idxmax()
print(highest_spending)
# Out:
# ('Los Angeles Lakers', 'SF')

# %%
position=np.unique(df['Position'])
print(position)
# Out:
# ['C' 'PF' 'PG' 'SF' 'SG']

# %%
segregate=df.groupby(['Position','Name'])
for position, name in segregate :
    print(position)
# Out:
# ('C', 'Al Horford')
# ('C', 'Al Jefferson')
# ('C', 'Alan Williams')
# ('C', 'Alex Len')
# ('C', 'Alexis Ajinca')
# ('C', 'Andre Drummond')
# ('C', 'Andrew Bogut')
# ('C', 'Aron Baynes')
# ('C', 'Bismack Biyombo')
# ('C', 'Boban Marjanovic')
# ('C', 'Boris Diaw')
# ('C', 'Brook Lopez')
# ('C', 'Chris Kaman')
# ('C', 'Cody Zeller')
# ('C', 'Cole Aldrich')
# ('C', 'DeAndre Jordan')
# ('C', 'DeMarcus Cousins')
# ('C', 'Dewayne Dedmon')
# ('C', 'Dwight Howard')
# ('C', 'Ed Davis')
# ('C', 'Enes Kanter')
# ('C', 'Festus Ezeli')
# ('C', 'Frank Kaminsky III')
# ('C', 'Gorgui Dieng')
# ('C', 'Greg Monroe')
# ('C', 'Hassan Whiteside')
# ('C', 'Henry Sims')
# ('C', 'Ian Mahinmi')
# ('C', 'JJ Hickson')
# ('C', 'JaVale McGee')
# ('C', 'Jahlil Okafor')
# ('C', 'Jared Sullinger')
# ('C', 'Jeff Withey')
# ('C', 'Joakim Noah')
# ('C', 'Joel Anthony')
# ('C', 'Joel Embiid')
# ('C', 'Joffrey Lauvergne')
# ('C', 'Jonas Valanciunas')
# ('C', 'Jordan Hill')
# ('C', 'Josh Smith')
# ('C', 'Jusuf Nurkic')
# ('C', 'Karl-Anthony Towns')
# ('C', 'Kelly Olynyk')
# ('C', 'Kendrick Perkins')
# ('C', 'Kevin Seraphin')
# ('C', 'Kosta Koufos')
# ('C', 'Lucas Nogueira')
# ('C', 'Marc Gasol')
# ('C', 'Marcin Gortat')
# ('C', 'Marreese Speights')
# ('C', 'Mason Plumlee')
# ('C', 'Matt Bonner')
# ('C', 'Miles Plumlee')
# ('C', 'Nazr Mohammed')
# ('C', 'Nene Hilario')
# ('C', 'Nikola Jokic')
# ('C', 'Nikola Pekovic')
# ('C', 'Nikola Vucevic')
# ('C', 'Omer Asik')
# ('C', 'Pau Gasol')
# ('C', 'Priyanka')
# ('C', 'Robert Sacre')
# ('C', 'Robin Lopez')
# ('C', 'Roy Hibbert')
# ('C', 'Rudy Gobert')
# ('C', 'Salah Mejri')
# ('C', 'Sasha Kaun')
# ('C', 'Steven Adams')
# ('C', 'Tarik Black')
# ('C', 'Tiago Splitter')
# ('C', 'Tibor Pleiss')
# ('C', 'Tim Duncan')
# ('C', 'Timofey Mozgov')
# ('C', 'Tristan Thompson')
# ('C', 'Tyler Zeller')
# ('C', 'Tyson Chandler')
# ('C', 'Walter Tavares')
# ('C', 'Willie Cauley-Stein')
# ('C', 'Zaza Pachulia')
# ('PF', 'Aaron Gordon')
# ('PF', 'Adreian Payne')
# ('PF', 'Alex Stepheson')
# ('PF', "Amar'e Stoudemire")
# ('PF', 'Amir Johnson')
# ('PF', 'Anderson Varejao')
# ('PF', 'Andrew Nicholson')
# ('PF', 'Anthony Davis')
# ('PF', 'Anthony Tolliver')
# ('PF', 'Blake Griffin')
# ('PF', 'Bobby Portis')
# ('PF', 'Brandan Wright')
# ('PF', 'Brandon Bass')
# ('PF', 'Cameron Bairstow')
# ('PF', 'Carl Landry')
# ('PF', 'Channing Frye')
# ('PF', 'Charlie Villanueva')
# ('PF', 'Chris Andersen')
# ('PF', 'Chris Bosh')
# ('PF', 'Chris McCullough')
# ('PF', 'Christian Wood')
# ('PF', 'Cliff Alexander')
# ('PF', 'Clint Capela')
# ('PF', 'Cristiano Felicio')
# ('PF', 'Dante Cunningham')
# ('PF', 'Darrell Arthur')
# ('PF', 'David Lee')
# ('PF', 'David West')
# ('PF', 'Derrick Favors')
# ('PF', 'Derrick Williams')
# ('PF', 'Dirk Nowitzki')
# ('PF', 'Donatas Motiejunas')
# ('PF', 'Draymond Green')
# ('PF', 'Drew Gooden')
# ('PF', 'Duje Dukan')
# ('PF', 'Dwight Powell')
# ('PF', 'Elton Brand')
# ('PF', 'Eric Moreland')
# ('PF', 'Ersan Ilyasova')
# ('PF', 'Greg Smith')
# ('PF', 'JaMychal Green')
# ('PF', 'Jabari Parker')
# ('PF', 'James Johnson')
# ('PF', 'Jarell Martin')
# ('PF', 'Jason Smith')
# ('PF', 'Jason Thompson')
# ('PF', 'Jeff Ayres')
# ('PF', 'John Henson')
# ('PF', "Johnny O'Bryant III")
# ('PF', 'Jon Leuer')
# ('PF', 'Jonas Jerebko')
# ('PF', 'Jordan Mickey')
# ('PF', 'Josh McRoberts')
# ('PF', 'Julius Randle')
# ('PF', 'Kenneth Faried')
# ('PF', 'Kevin Garnett')
# ('PF', 'Kevin Love')
# ('PF', 'Kris Humphries')
# ('PF', 'Kristaps Porzingis')
# ('PF', "Kyle O'Quinn")
# ('PF', 'LaMarcus Aldridge')
# ('PF', 'Larry Nance Jr.')
# ('PF', 'Lavoy Allen')
# ('PF', 'Lou Amundson')
# ('PF', 'Luc Richard Mbah a Moute')
# ('PF', 'Luis Scola')
# ('PF', 'Marcus Morris')
# ('PF', 'Markieff Morris')
# ('PF', 'Marvin Williams')
# ('PF', 'Meyers Leonard')
# ('PF', 'Mike Muscala')
# ('PF', 'Mike Scott')
# ('PF', 'Mirza Teletovic')
# ('PF', 'Mitch McGary')
# ('PF', 'Montrezl Harrell')
# ('PF', 'Myles Turner')
# ('PF', 'Nemanja Bjelica')
# ('PF', 'Nerlens Noel')
# ('PF', 'Nick Collison')
# ('PF', 'Nikola Mirotic')
# ('PF', 'Noah Vonleh')
# ('PF', 'Patrick Patterson')
# ('PF', 'Paul Millsap')
# ('PF', 'Rakeem Christmas')
# ('PF', 'Richaun Holmes')
# ('PF', 'Ryan Anderson')
# ('PF', 'Ryan Kelly')
# ('PF', 'Serge Ibaka')
# ('PF', 'Shayne Whittington')
# ('PF', 'Spencer Hawes')
# ('PF', 'Taj Gibson')
# ('PF', 'Terrence Jones')
# ('PF', 'Thaddeus Young')
# ('PF', 'Thomas Robinson')
# ('PF', 'Trevor Booker')
# ('PF', 'Trey Lyles')
# ('PF', 'Tyler Hansbrough')
# ('PF', 'Udonis Haslem')
# ('PF', 'Willie Reed')
# ('PF', 'Zach Randolph')
# ('PG', 'Aaron Brooks')
# ('PG', 'Andre Miller')
# ('PG', 'Andrew Goudelock')
# ('PG', 'Austin Rivers')
# ('PG', 'Avery Bradley')
# ('PG', 'Brandon Jennings')
# ('PG', 'Brandon Knight')
# ('PG', 'Brian Roberts')
# ('PG', 'Briante Weber')
# ('PG', 'Bryce Cotton')
# ('PG', 'C.J. Watson')
# ('PG', 'Cameron Payne')
# ('PG', 'Chris Paul')
# ('PG', 'Cory Joseph')
# ('PG', "D'Angelo Russell")
# ('PG', 'D.J. Augustin')
# ('PG', 'Damian Lillard')
# ('PG', 'Dante Exum')
# ('PG', 'Darren Collison')
# ('PG', 'Delon Wright')
# ('PG', 'Dennis Schroder')
# ('PG', 'Deron Williams')
# ('PG', 'Derrick Rose')
# ('PG', 'Devin Harris')
# ('PG', 'Donald Sloan')
# ('PG', 'Elfrid Payton')
# ('PG', 'Emmanuel Mudiay')
# ('PG', 'Eric Bledsoe')
# ('PG', 'George Hill')
# ('PG', 'Goran Dragic')
# ('PG', 'Greivis Vasquez')
# ('PG', 'Isaiah Canaan')
# ('PG', 'Isaiah Thomas')
# ('PG', 'Ish Smith')
# ('PG', 'J.J. Barea')
# ('PG', 'Jameer Nelson')
# ('PG', 'Jarrett Jack')
# ('PG', 'Jeff Teague')
# ('PG', 'Jeremy Lin')
# ('PG', 'Jerian Grant')
# ('PG', 'Jerryd Bayless')
# ('PG', 'Joe Young')
# ('PG', 'John Wall')
# ('PG', 'Jordan Clarkson')
# ('PG', 'Jordan Farmar')
# ('PG', 'Jorge Gutierrez')
# ('PG', 'Jose Calderon')
# ('PG', 'Jrue Holiday')
# ('PG', 'Kemba Walker')
# ('PG', 'Kendall Marshall')
# ('PG', 'Kyle Lowry')
# ('PG', 'Kyrie Irving')
# ('PG', 'Lorenzo Brown')
# ('PG', 'Marcelo Huertas')
# ('PG', 'Marcus Smart')
# ('PG', 'Matthew Dellavedova')
# ('PG', 'Michael Carter-Williams')
# ('PG', 'Mike Conley')
# ('PG', 'Mo Williams')
# ('PG', 'Norris Cole')
# ('PG', 'Pablo Prigioni')
# ('PG', 'Patrick Beverley')
# ('PG', 'Patty Mills')
# ('PG', 'Phil Pressey')
# ('PG', 'Rajon Rondo')
# ('PG', 'Ramon Sessions')
# ('PG', 'Raul Neto')
# ('PG', 'Ray McCallum')
# ('PG', 'Raymond Felton')
# ('PG', 'Reggie Jackson')
# ('PG', 'Ricky Rubio')
# ('PG', 'Rodney Stuckey')
# ('PG', 'Ronnie Price')
# ('PG', 'Russell Westbrook')
# ('PG', 'Shabazz Napier')
# ('PG', 'Shane Larkin')
# ('PG', 'Shaun Livingston')
# ('PG', 'Shelvin Mack')
# ('PG', 'Spencer Dinwiddie')
# ('PG', 'Stephen Curry')
# ('PG', 'Steve Blake')
# ('PG', 'T.J. McConnell')
# ('PG', 'Terry Rozier')
# ('PG', 'Tim Frazier')
# ('PG', 'Toney Douglas')
# ('PG', 'Tony Parker')
# ('PG', 'Trey Burke')
# ('PG', 'Ty Lawson')
# ('PG', 'Tyler Ennis')
# ('PG', 'Tyus Jones')
# ('PG', 'Xavier Munford')
# ('PG', 'Zach LaVine')
# ('SF', 'Al-Farouq Aminu')
# ('SF', 'Alonzo Gee')
# ('SF', 'Andre Iguodala')
# ('SF', 'Anthony Brown')
# ('SF', 'Branden Dawson')
# ('SF', 'Brandon Rush')
# ('SF', 'Bruno Caboclo')
# ('SF', 'C.J. Miles')
# ('SF', 'Carmelo Anthony')
# ('SF', 'Caron Butler')
# ('SF', 'Chandler Parsons')
# ('SF', 'Chase Budinger')
# ('SF', 'Chris Johnson')
# ('SF', 'Cleanthony Early')
# ('SF', 'Damien Inglis')
# ('SF', 'Damjan Rudez')
# ('SF', 'Danilo Gallinari')
# ('SF', 'Darrun Hilliard')
# ('SF', 'DeMarre Carroll')
# ('SF', 'Devyn Marble')
# ('SF', 'Dorell Wright')
# ('SF', 'Doug McDermott')
# ('SF', 'Gerald Green')
# ('SF', 'Giannis Antetokounmpo')
# ('SF', 'Gordon Hayward')
# ('SF', 'Harrison Barnes')
# ('SF', 'Jae Crowder')
# ('SF', 'James Ennis')
# ('SF', 'James Michael McAdoo')
# ('SF', 'Jared Dudley')
# ('SF', 'Jeff Green')
# ('SF', 'Jerami Grant')
# ('SF', 'Jeremy Evans')
# ('SF', 'Joe Ingles')
# ('SF', 'Joe Johnson')
# ('SF', 'Josh Huestis')
# ('SF', 'Justise Winslow')
# ('SF', 'Kawhi Leonard')
# ('SF', 'Kelly Oubre Jr.')
# ('SF', 'Kent Bazemore')
# ('SF', 'Kevin Durant')
# ('SF', 'Kevon Looney')
# ('SF', 'Kobe Bryant')
# ('SF', 'Kyle Anderson')
# ('SF', 'Kyle Singler')
# ('SF', 'Lance Stephenson')
# ('SF', 'Lance Thomas')
# ('SF', 'LeBron James')
# ('SF', 'Luke Babbitt')
# ('SF', 'Luol Deng')
# ('SF', 'Marcus Thornton')
# ('SF', 'Matt Barnes')
# ('SF', 'Maurice Harkless')
# ('SF', 'Metta World Peace')
# ('SF', 'Michael Beasley')
# ('SF', 'Michael Kidd-Gilchrist')
# ('SF', 'Nick Young')
# ('SF', 'Omri Casspi')
# ('SF', 'Otto Porter Jr.')
# ('SF', 'P.J. Hairston')
# ('SF', 'P.J. Tucker')
# ('SF', 'Paul George')
# ('SF', 'Paul Pierce')
# ('SF', 'Quincy Acy')
# ('SF', 'Quincy Pondexter')
# ('SF', 'Reggie Bullock')
# ('SF', 'Richard Jefferson')
# ('SF', 'Robert Covington')
# ('SF', 'Rudy Gay')
# ('SF', 'Sam Dekker')
# ('SF', 'Shabazz Muhammad')
# ('SF', 'Solomon Hill')
# ('SF', 'Stanley Johnson')
# ('SF', 'Steve Novak')
# ('SF', 'T.J. Warren')
# ('SF', 'Tayshaun Prince')
# ('SF', 'Terrence Ross')
# ('SF', 'Thabo Sefolosha')
# ('SF', 'Thanasis Antetokounmpo')
# ('SF', 'Tobias Harris')
# ('SF', 'Tony Snell')
# ('SF', 'Trevor Ariza')
# ('SF', 'Wesley Johnson')
# ('SF', 'Will Barton')
# ('SF', 'Wilson Chandler')
# ('SG', 'Aaron Harrison')
# ('SG', 'Alan Anderson')
# ('SG', 'Alec Burks')
# ('SG', 'Allen Crabbe')
# ('SG', 'Andre Roberson')
# ('SG', 'Andrew Wiggins')
# ('SG', 'Anthony Morrow')
# ('SG', 'Archie Goodwin')
# ('SG', 'Arron Afflalo')
# ('SG', 'Axel Toupane')
# ('SG', 'Ben McLemore')
# ('SG', 'Bojan Bogdanovic')
# ('SG', 'Bradley Beal')
# ('SG', 'Bryce Dejean-Jones')
# ('SG', 'C.J. McCollum')
# ('SG', 'C.J. Wilcox')
# ('SG', 'Corey Brewer')
# ('SG', 'Courtney Lee')
# ('SG', 'Dahntay Jones')
# ('SG', 'Danny Green')
# ('SG', 'DeMar DeRozan')
# ('SG', 'Devin Booker')
# ('SG', 'Dion Waiters')
# ('SG', 'Dwyane Wade')
# ('SG', "E'Twaun Moore")
# ('SG', 'Eric Gordon')
# ('SG', 'Evan Fournier')
# ('SG', 'Evan Turner')
# ('SG', 'Garrett Temple')
# ('SG', 'Gary Harris')
# ('SG', 'Gerald Henderson')
# ('SG', 'Glenn Robinson III')
# ('SG', 'Hollis Thompson')
# ('SG', 'Ian Clark')
# ('SG', 'Iman Shumpert')
# ('SG', 'J.R. Smith')
# ('SG', 'JJ Redick')
# ('SG', 'JaKarr Sampson')
# ('SG', 'Jamal Crawford')
# ('SG', 'James Anderson')
# ('SG', 'James Harden')
# ('SG', 'James Jones')
# ('SG', 'James Young')
# ('SG', 'Jared Cunningham')
# ('SG', 'Jarell Eddie')
# ('SG', 'Jason Terry')
# ('SG', 'Jeremy Lamb')
# ('SG', 'Jimmy Butler')
# ('SG', 'Jodie Meeks')
# ('SG', 'John Holland')
# ('SG', 'John Jenkins')
# ('SG', 'Jonathon Simmons')
# ('SG', 'Jordan Adams')
# ('SG', 'Jordan Hamilton')
# ('SG', 'Jordan McRae')
# ('SG', 'Josh Richardson')
# ('SG', 'Justin Anderson')
# ('SG', 'Justin Holiday')
# ('SG', 'K.J. McDaniels')
# ('SG', 'Kentavious Caldwell-Pope')
# ('SG', 'Kevin Martin')
# ('SG', 'Khris Middleton')
# ('SG', 'Kirk Hinrich')
# ('SG', 'Klay Thompson')
# ('SG', 'Kyle Korver')
# ('SG', 'Lamar Patterson')
# ('SG', 'Langston Galloway')
# ('SG', 'Leandro Barbosa')
# ('SG', 'Louis Williams')
# ('SG', 'Luis Montero')
# ('SG', 'Manu Ginobili')
# ('SG', 'Marco Belinelli')
# ('SG', 'Mario Hezonja')
# ('SG', 'Markel Brown')
# ('SG', 'Mike Dunleavy')
# ('SG', 'Mike Miller')
# ('SG', 'Monta Ellis')
# ('SG', 'Nicolas Batum')
# ('SG', 'Nik Stauskas')
# ('SG', 'Norman Powell')
# ('SG', 'O.J. Mayo')
# ('SG', 'Orlando Johnson')
# ('SG', 'Pat Connaughton')
# ('SG', 'R.J. Hunter')
# ('SG', 'Randy Foye')
# ('SG', 'Rashad Vaughn')
# ('SG', 'Rodney Hood')
# ('SG', 'Rondae Hollis-Jefferson')
# ('SG', 'Sasha Vujacic')
# ('SG', 'Sean Kilpatrick')
# ('SG', 'Sergey Karasev')
# ('SG', 'Seth Curry')
# ('SG', 'Tim Hardaway Jr.')
# ('SG', 'Tony Allen')
# ('SG', 'Tony Wroten')
# ('SG', 'Troy Daniels')
# ('SG', 'Tyler Johnson')
# ('SG', 'Tyreke Evans')
# ('SG', 'Victor Oladipo')
# ('SG', 'Vince Carter')
# ('SG', 'Wayne Ellington')
# ('SG', 'Wesley Matthews')

# %% [markdown]
# # age

# %%
age_count=employee_df['Age'].count()
print(age_count)
